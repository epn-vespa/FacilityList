# %%
from parsers import *

# %%
set_data_dir("../data/")

# %%
aas = load_aas_list()

# %%
for item in aas:
    print(aas[item]['alternateName'])
# Out:
# [{'name': "NASA's Polarimeter to UNify the Corona and Heliosphere (PUNCH) mission", 'namingAuthority': 'aas'}, {'name': 'PUNCH', 'namingAuthority': 'aas'}]
# [{'name': 'The Vera C. Rubin 8.4m Simonyi Survey Telescope Observatory', 'namingAuthority': 'aas'}, {'name': 'Rubin', 'namingAuthority': 'aas'}]
# [{'name': "Harvard and Smithsonian Center for Astrophysics' MicroObservatory Robotic Telescope Network", 'namingAuthority': 'aas'}, {'name': 'MRTN', 'namingAuthority': 'aas'}]
# [{'name': 'The Deep Space Network, radio astronomy observations with 34 m at Madrid', 'namingAuthority': 'aas'}, {'name': 'DSN:DSS-65', 'namingAuthority': 'aas'}]
# [{'name': 'The Deep Space Network, radio astronomy observations with 70 m at Madrid', 'namingAuthority': 'aas'}, {'name': 'DSN:DSS-63', 'namingAuthority': 'aas'}]
# [{'name': 'The Deep Space Network, radio astronomy observations with 34 m at Madrid', 'namingAuthority': 'aas'}, {'name': 'DSN:DSS-56', 'namingAuthority': 'aas'}]
# ...

# %% [raw]
# [{'name': 'NASA/European Space Agency (ESA) 2.4m Hubble Space Telescope (HST) Satellite Mission', 'namingAuthority': 'aas'}, {'name': 'HST', 'namingAuthority': 'aas'}, {'name': 'HST', 'namingAuthority': 'naif'}, {'name': '-48', 'namingAuthority': 'naif'}]
